# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))
from run import Orchestrator
o = Orchestrator()
o.step("明天去医院")
o.step("是的，帮我记录一下")
# Out:
# {'reply': '好的，该日志已保存！', 'state': 'S1', 'saved': True}
